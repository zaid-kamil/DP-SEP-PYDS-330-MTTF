# %% [markdown]
# # Data analysis
# 0. Import the libraries
# 1. Load the data
# 2. Check the data and understand it.
# 3. Preprocess the data
# 4. Explore the data
# 5. Visualize the data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/indian_cities.csv')

# %%
df
# Out:
#      Rank        City           State  Population  Metro_Population  Sexratio  \
# 0       1      Mumbai     Maharashtra    12442373          18414288       853
# 1       2       Delhi           Delhi    11034555          16314838       876
# 2       3   Bangalore       Karnataka     8443675           8499399       923
# 3       4   Hyderabad  Andhra Pradesh     6731790           7749334       955
# 4       5   Ahmedabad         Gujarat     5577940           6352254       898
# ..    ...         ...             ...         ...               ...       ...
# 493   494     Gangtok          Sikkim      100286            100286       912
# 494   495       Datia  Madhya Pradesh      100284            100284       900
# 495   496       Nagda  Madhya Pradesh      100039            100039       947
# 496   497    Banswara       Rajasthan       99969            101177       960
# 497   498  Kapurthala          Punjab       98916             98916       839
#
#      Literacy
# 0       89.73
# 1       87.59
# 2       88.71
# 3       83.26
# 4       88.29
# ..        ...
# 493     89.33
# 494     80.56
# 495     80.71
# 496     85.72
# 497     85.08
#
# [498 rows x 7 columns]

# %%
df2 =  pd.read_excel('data/report.xlsx')

# %%
df2
# Out:
#       Student  Hindi  English  Maths  Science
# 0      Anchal     45       85     34       34
# 1   Divyanshi     90       34     23       96
# 2       Priya     59       39     65       67
# 3     Anshika     45       23     56       23
# 4      Nikita     67       67     34       67
# 5       Gopal     49       34     45       34
# 6       Ankit     38       84     38       54
# 7  Shubhankar     67       34     23       67

# %%
df.head(n=2)
# Out:
#    Rank    City        State  Population  Metro_Population  Sexratio  Literacy
# 0     1  Mumbai  Maharashtra    12442373          18414288       853     89.73
# 1     2   Delhi        Delhi    11034555          16314838       876     87.59

# %%
df.tail()
# Out:
#      Rank        City           State  Population  Metro_Population  Sexratio  \
# 493   494     Gangtok          Sikkim      100286            100286       912
# 494   495       Datia  Madhya Pradesh      100284            100284       900
# 495   496       Nagda  Madhya Pradesh      100039            100039       947
# 496   497    Banswara       Rajasthan       99969            101177       960
# 497   498  Kapurthala          Punjab       98916             98916       839
#
#      Literacy
# 493     89.33
# 494     80.56
# 495     80.71
# 496     85.72
# 497     85.08

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 498 entries, 0 to 497
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Rank              498 non-null    int64
#  1   City              498 non-null    object
#  2   State             498 non-null    object
#  3   Population        498 non-null    int64
#  4   Metro_Population  498 non-null    int64
#  5   Sexratio          498 non-null    int64
#  6   Literacy          498 non-null    float64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 27.4+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Student  8 non-null      object
#  1   Hindi    8 non-null      int64
#  2   English  8 non-null      int64
#  3   Maths    8 non-null      int64
#  4   Science  8 non-null      int64
# dtypes: int64(4), object(1)
# memory usage: 448.0+ bytes

# %%
df2.describe()
# Out:
#           Hindi   English      Maths    Science
# count   8.00000   8.00000   8.000000   8.000000
# mean   57.50000  50.00000  39.750000  55.250000
# std    16.91998  24.75018  14.926008  23.962769
# min    38.00000  23.00000  23.000000  23.000000
# 25%    45.00000  34.00000  31.250000  34.000000
# 50%    54.00000  36.50000  36.000000  60.500000
# 75%    67.00000  71.25000  47.750000  67.000000
# max    90.00000  85.00000  65.000000  96.000000

# %%
df.describe()
# Out:
#              Rank    Population  Metro_Population     Sexratio    Literacy
# count  498.000000  4.980000e+02      4.980000e+02   498.000000  498.000000
# mean   249.500000  4.498030e+05      5.556033e+05   932.903614   84.261004
# std    143.904482  1.029319e+06      1.501008e+06    55.392315    6.306394
# min      1.000000  9.891600e+04      9.891600e+04   709.000000   48.280000
# 25%    125.250000  1.256420e+05      1.384625e+05   894.250000   80.945000
# 50%    249.500000  1.841050e+05      2.048060e+05   925.000000   85.180000
# 75%    373.750000  3.495960e+05      4.103862e+05   975.500000   88.612500
# max    498.000000  1.244237e+07      1.841429e+07  1093.000000   98.360000

# %%
df.describe(exclude=np.number)
# Out:
#               City          State
# count          498            498
# unique         497             30
# top     Aurangabad  Uttar Pradesh
# freq             2             64

# %%
df.isnull().sum()
# Out:
# Rank                0
# City                0
# State               0
# Population          0
# Metro_Population    0
# Sexratio            0
# Literacy            0
# dtype: int64

# %%
df2.columns
# Out:
# Index(['Student', 'Hindi', 'English', 'Maths', 'Science'], dtype='object')

# %%
df2['Total'] = df2['English'] + df2['Hindi'] + df2['Maths'] + df2['Science']

# %%
df2
# Out:
#       Student  Hindi  English  Maths  Science  Total
# 0      Anchal     45       85     34       34    198
# 1   Divyanshi     90       34     23       96    243
# 2       Priya     59       39     65       67    230
# 3     Anshika     45       23     56       23    147
# 4      Nikita     67       67     34       67    235
# 5       Gopal     49       34     45       34    162
# 6       Ankit     38       84     38       54    214
# 7  Shubhankar     67       34     23       67    191

# %%
df2['Total'].plot(kind='bar', figsize=(15,5))
# Out:
# <AxesSubplot: >
